# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('d_DL1.csv')
df['target_date'] = pd.to_datetime(df['target_date'])

# %%
f,ax = plt.subplots(figsize=(40,10))
plt.plot(df['target_date'], df['d_target'])
plt.plot(df['target_date'], df['d_DL1'])
